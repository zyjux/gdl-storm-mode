# %%
from glob import glob
from os.path import join
import xarray as xr

# %%
# Find a list of all the datafiles
patch_path = "/glade/scratch/lverhoef/WRF_all/track_data_hrrr_3km_nc_refl/"
patch_files = sorted(glob(join(patch_path, "*.nc")))
csv_path = "/glade/scratch/lverhoef/WRF_all/track_data_hrrr_3km_csv_refl/"
csv_files = sorted(glob(join(csv_path, "track_step_*.csv")))

# %%
comb_patch_path = "/glade/scratch/lverhoef/WRF_all/track_data_hrrr_3km_nc_refl/patch_combined.nc"
comb_csv_path = "/glade/scratch/lverhoef/WRF_all/track_data_hrrr_3km_csv_refl/csv_combined.nc"

# %%
ds_big = xr.open_dataset(patch_files[0])
for file in patch_files[1:]:
    ds = xr.open_dataset(file)
    ds_big = xr.concat([ds_big, ds], p

# %%
ds = xr.open_mfdataset(join(patch_path, "*.nc"), combine="nested", parallel=True)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 ds = xr.open_mfdataset(join(patch_path, "*.nc"), combine="nested", parallel=True)
#
# File ~/.conda/envs/storm-mode/lib/python3.10/site-packages/xarray/backends/api.py:923, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     919 try:
#     920     if combine == "nested":
#     921         # Combined nested list by successive concat and merge operations
#     922         # along each dimension, using structure given by "ids"
# --> 923         combined = _nested_combine(
#     924             datasets,
#     925             concat_dims=concat_dim,
#     926             compat=compat,
#     927             data_vars=data_vars,
#     928             coords=coords,
# ...

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:           (p: 811, row: 144, col: 144)
# Coordinates:
#   * p                 (p) int64 0 1 2 3 4 5 6 7 ... 804 805 806 807 808 809 810
#   * row               (row) int32 0 1 2 3 4 5 6 ... 137 138 139 140 141 142 143
#   * col               (col) int32 0 1 2 3 4 5 6 ... 137 138 139 140 141 142 143
# Data variables: (12/26)
#     lon               (p, row, col) float32 dask.array<open_dataset-aa3da00ed...
#     lat               (p, row, col) float32 dask.array<open_dataset-aa3da00ed...
#     i                 (p, row, col) int32 dask.array<open_dataset-aa3da00edb0...
#     j                 (p, row, col) int32 dask.array<open_dataset-aa3da00edb0...
#     x                 (p, row, col) float32 dask.array<open_dataset-aa3da00ed...
#     y                 (p, row, col) float32 dask.array<open_dataset-aa3da00ed...
#     ...                ...
#     MLCAPE_prev       (p, row, col) float32 dask.array<open_dataset-aa3da00ed...
# ...
